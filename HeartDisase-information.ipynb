# %%
# import the necessary modules
# pip install pandas
# pip3 install pandas

import pandas as  pd 
import numpy as  np
#import nlp_rake
import matplotlib.pyplot as plt

import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import seaborn as sns

# %%
#read data with modül of pandas 
df = pd.read_csv("C:\DataScience_FinalProject\data\heart.csv")

# %%
df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
import pandas as pd
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (1025, 14)

# %%
# pip3 install scikit-learn
# pip install scikit-learn

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# Group by 'sex' and 'target' and count occurrences
count_data = df.groupby(['sex', 'target']).size().unstack()

# Plot a bar chart
count_data.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Sex (1: Female, 0: Male)')
plt.ylabel('Count')
plt.title('Distribution of Target by Sex')

# Show the plot
plt.show()

# %%
sns.histplot(data=df, x='age', kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sick_women = df[(df['sex'] == 1) & (df['target'] == 1)].shape[0]
sick_men = df[(df['sex'] == 0) & (df['target'] == 1)].shape[0]

# Create a pie chart
labels = ['Patient Women', 'Patient Men']
sizes = [sick_women, sick_men]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Make the pie chart circular
plt.title('Percentage of Sick Women and Men')
plt.show()

# %%
sns.histplot(df['age'][df['target']==1], kde=True, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age Distribution of Sick Patients')

# Show the plot
plt.show()
